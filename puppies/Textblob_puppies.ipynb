# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import re
from datetime import date
from textblob import TextBlob

df3=pd.read_csv('pupfile_ready0.xls','\t')

# %%
df3.days_on_site.value_counts()
# Out:
# 1     1972
# 0     1340
# 12    1015
# 13     592
# 84     416
# 14     282
# 11     232
# 19      54
# 24      27
# 16      25
# 21      22
# 66      21
# 45      18
# 29      17
# 17      17
# 67      15
# 49      14
# 20      14
# 26      13
# 39      13
# 18      12
# 81      11
# 40      11
# 30      11
# 35      11
# 54      10
# 48      10
# 37      10
# 41      10
# 31      10
#       ...
# 65       7
# 82       7
# 64       7
# 63       6
# 33       6
# 60       5
# 46       5
# 77       5
# 43       5
# 23       5
# 57       5
# 56       5
# 52       4
# 80       4
# 71       4
# 44       4
# 50       4
# 53       4
# 73       3
# 72       3
# 76       3
# 69       3
# 70       3
# 55       3
# 32       2
# 79       2
# 74       2
# 68       1
# 78       1
# 83       1
# Name: days_on_site, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(df3.days_on_site, bins=10, color='blue')
# Out:
# (array([ 3312.,  2146.,   160.,    77.,    78.,    77.,    47.,    87.,
#            19.,   450.]),
#  array([  0. ,   8.4,  16.8,  25.2,  33.6,  42. ,  50.4,  58.8,  67.2,
#          75.6,  84. ]),
#  <a list of 10 Patch objects>)

# %%
for a in df3.Description:
    if not pd.isnull(a):
        b=a.decode('utf8')
        m=TextBlob(b)
        print m.sentiment
print a
# Out:
# Sentiment(polarity=0.19921874999999997, subjectivity=0.41822916666666665)
# Sentiment(polarity=0.35625, subjectivity=0.5381944444444445)
# Sentiment(polarity=0.22997497294372296, subjectivity=0.529906204906205)
# Sentiment(polarity=0.28491379310344833, subjectivity=0.5)
# Sentiment(polarity=0.29690476190476195, subjectivity=0.5554761904761905)
# Sentiment(polarity=-0.06666666666666667, subjectivity=0.16666666666666666)
# Sentiment(polarity=0.23902867965367963, subjectivity=0.5188852813852814)
# Sentiment(polarity=0.3456845238095238, subjectivity=0.6359619047619046)
# Sentiment(polarity=0.4010248447204969, subjectivity=0.6211387163561076)
# Sentiment(polarity=0.2625, subjectivity=0.4513888888888889)
# Sentiment(polarity=0.16917989417989418, subjectivity=0.7047619047619047)
# Sentiment(polarity=0.28942550505050507, subjectivity=0.5297979797979798)
# Sentiment(polarity=0.25021303258145366, subjectivity=0.5573475355054303)
# ...
